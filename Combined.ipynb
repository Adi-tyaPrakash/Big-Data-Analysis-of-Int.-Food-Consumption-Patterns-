# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Cleaned_Data.csv")
df.head(5)
# Out:
#    Category.Code  Dry_Matter     Energy   Protein  Fiber_TD   FA_Poly  \
# 0              1    0.003448  15.052479  0.000344  0.000091  0.000040
# 1              1    0.000625   2.722306  0.000051  0.000007  0.000016
# 2              1    0.003832  18.699123  0.000353  0.000024  0.000207
# 3              1    0.006113  24.027299  0.000585  0.000060  0.000078
# 4              1    0.000886   2.478998  0.000150  0.000128  0.000046
#
#         Calcium          Iron     Magnesium    Phosphorus  ...        Vit_B6  \
# 0  2.177000e-06  2.390000e-07  5.820000e-07  2.857000e-06  ...  6.000000e-09
# 1  2.000000e-06  6.400000e-08  5.300000e-08  3.730000e-07  ...  2.000000e-09
# 2  5.931000e-06  7.400000e-08  2.270000e-07  1.943000e-06  ...  0.000000e+00
# 3  3.355000e-06  9.700000e-08  4.380000e-07  2.348000e-06  ...  1.000000e-09
# 4  9.360000e-07  6.300000e-08  1.747000e-06  4.421000e-06  ...  2.000000e-09
#
#    Choline_Tot         Vit_E  Vit_A    Folate_Tot  Vit_B12  Vit_K  \
# ...

# %%
excluded_columns = ['Category.Code','Importer_Country','Exporter_Country','Item_List']

# %%
grouped_df = df.groupby(['Exporter_Country', 'Importer_Country'])['Vit_A'].sum().reset_index()

# %%
grouped_df.head(3)
# Out:
#   Exporter_Country Importer_Country         Vit_A
# 0      Afghanistan      Afghanistan  2.045584e+00
# 1      Afghanistan          Albania  2.400000e-07
# 2      Afghanistan          Algeria  8.327000e-06

# %%
# df2 = pd.read_csv("C:/Users/ASUS/OneDrive/Desktop/Research_Papers/Vit_B12/Table_S1_iron.csv")
df2 = pd.read_csv("C:/Users/ASUS/OneDrive/Desktop/Research_Papers/Vit_B12/Tabble_S2_iron.csv")

# %%
df2.head(100)
# Out:
#     Country Area Code              Country  Total Iron produced per year  \
# 0                   2          Afghanistan                           NaN
# 1                   3              Albania                           NaN
# 2                   4              Algeria                           NaN
# 3                   7               Angola                           NaN
# 4                   8  Antigua and Barbuda                           NaN
# ..                ...                  ...                           ...
# 95                110                Japan                           NaN
# 96                112               Jordan                           NaN
# 97                108           Kazakhstan                           NaN
# 98                114                Kenya                           NaN
# 99                 83             Kiribati                           NaN
#
#     Number of export partner countries  export partner country name-1  \
# ...

# %%
# Ensure the columns are of type 'object' before making the assignments
columns_to_modify = [
    'export partner country name-1',
    'export partner country name-2',
    'export partner country name-3',
    'export partner country name-4',
    'export partner country name-5',
    'export partner country name-6',
    '% of total iron to export partner-1',
    '% of total iron to export partner-2',
    '% of total iron to export partner-3',
    '% of total iron to export partner-4',
    '% of total iron to export partner-5',
    '% of total iron to export partner-6'
]

for column in columns_to_modify:
    df2[column] = df2[column].astype(object)

df_list = []
for country in df2['Country']:
    total_energy = 0
    count = 0
    imp_cty = []
    energy = []
    for i in range(len(grouped_df['Exporter_Country'])):
        curr_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Exporter_Country')]
        
        if country == curr_cty:
            Imp_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Importer_Country')]
            Energy = grouped_df.iloc[i, grouped_df.columns.get_loc('Iron')]
            total_energy += Energy
            energy.append(Energy)
            imp_cty.append(Imp_cty)
            count += 1
            
    df2.loc[df2['Country'] == country, 'Total Iron produced per year'] = total_energy
    df2.loc[df2['Country'] == country, 'Number of export partner countries'] = count
    df = pd.DataFrame({'Imp_Country': imp_cty, 'Energy': energy})
    df.sort_values(by=['Energy'], ascending=False, inplace=True)
    
    try:
        cty_1 = df['Imp_Country'].iloc[0]
        df2.loc[df2['Country'] == country, 'export partner country name-1'] = cty_1
        cty_2 = df['Imp_Country'].iloc[1]
        df2.loc[df2['Country'] == country, 'export partner country name-2'] = cty_2
        cty_3 = df['Imp_Country'].iloc[2]
        df2.loc[df2['Country'] == country, 'export partner country name-3'] = cty_3
        cty_4 = df['Imp_Country'].iloc[3]
        df2.loc[df2['Country'] == country, 'export partner country name-4'] = cty_4
        cty_5 = df['Imp_Country'].iloc[4]
        df2.loc[df2['Country'] == country, 'export partner country name-5'] = cty_5
        cty_6 = df['Imp_Country'].iloc[5]
        df2.loc[df2['Country'] == country, 'export partner country name-6'] = cty_6
        
        calorie_1 = (df['Energy'].iloc[0] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron to export partner-1'] = calorie_1
        calorie_2 = (df['Energy'].iloc[1] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron to export partner-2'] = calorie_2
        calorie_3 = (df['Energy'].iloc[2] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron to export partner-3'] = calorie_3
        calorie_4 = (df['Energy'].iloc[3] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron to export partner-4'] = calorie_4
        calorie_5 = (df['Energy'].iloc[4] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron to export partner-5'] = calorie_5
        calorie_6 = (df['Energy'].iloc[5] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron to export partner-6'] = calorie_6
        
    except IndexError:
        print(f"No import partner found for {country}. Moving to the next country.")
        continue

    df_list.append(df)
# Out:
# No import partner found for Belgium-Luxembourg. Moving to the next country.
# No import partner found for Czechoslovakia. Moving to the next country.
# No import partner found for Ethiopia PDR. Moving to the next country.
# No import partner found for French Guiana. Moving to the next country.
# No import partner found for Guadeloupe. Moving to the next country.
# No import partner found for Martinique. Moving to the next country.
# No import partner found for Réunion. Moving to the next country.

# %%
# Ensure the columns are of type 'object' before making the assignments
columns_to_modify = [
    'Import partner country name-1',
    'Import partner country name-2',
    'Import partner country name-3',
    'Import partner country name-4',
    'Import partner country name-5',
    'Import partner country name-6',
    '% of total iron from import partner-1',
    '% of total iron from import partner-2',
    '% of total iron from import partner-3',
    '% of total iron from import partner-4',
    '% of total iron from import partner-5',
    '% of total iron from import partner-6'
]

for column in columns_to_modify:
    df2[column] = df2[column].astype(object)

df_list = []
for country in df2['Country']:
    total_energy = 0
    count = 0
    exp_cty = []
    energy = []
    for i in range(len(grouped_df['Importer_Country'])):
        curr_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Importer_Country')]
        
        if(country == curr_cty):
            Exp_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Exporter_Country')]
            Energy = grouped_df.iloc[i, grouped_df.columns.get_loc('Iron')]
            total_energy += Energy
            energy.append(Energy)
            exp_cty.append(Exp_cty)
            count = int(count) + 1
            
    df2.loc[df2['Country'] == country, 'Total Iron consumed per year'] = total_energy
    df2.loc[df2['Country'] == country, 'Number of import partner countries'] = count
    df = pd.DataFrame({'Exp_Country': exp_cty, 'Energy': energy})
    df.sort_values(by=['Energy'], ascending=False, inplace=True)
    
    try:
        cty_1 = df['Exp_Country'].iloc[0]
        df2.loc[df2['Country'] == country, 'Import partner country name-1'] = cty_1
        cty_2 = df['Exp_Country'].iloc[1]
        df2.loc[df2['Country'] == country, 'Import partner country name-2'] = cty_2
        cty_3 = df['Exp_Country'].iloc[2]
        df2.loc[df2['Country'] == country, 'Import partner country name-3'] = cty_3
        cty_4 = df['Exp_Country'].iloc[3]
        df2.loc[df2['Country'] == country, 'Import partner country name-4'] = cty_4
        cty_5 = df['Exp_Country'].iloc[4]
        df2.loc[df2['Country'] == country, 'Import partner country name-5'] = cty_5
        cty_6 = df['Exp_Country'].iloc[5]
        df2.loc[df2['Country'] == country, 'Import partner country name-6'] = cty_6
        
        calorie_1 = (df['Energy'].iloc[0] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron from import partner-1'] = calorie_1
        calorie_2 = (df['Energy'].iloc[1] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron from import partner-2'] = calorie_2
        calorie_3 = (df['Energy'].iloc[2] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron from import partner-3'] = calorie_3
        calorie_4 = (df['Energy'].iloc[3] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron from import partner-4'] = calorie_4
        calorie_5 = (df['Energy'].iloc[4] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron from import partner-5'] = calorie_5
        calorie_6 = (df['Energy'].iloc[5] / total_energy) * 100
        df2.loc[df2['Country'] == country, '% of total iron from import partner-6'] = calorie_6
        
    except IndexError:
        print(f"No import partner found for {country}. Moving to the next country.")
        continue

    df_list.append(df)
# Out:
# No import partner found for Belgium-Luxembourg. Moving to the next country.
# No import partner found for Brunei Darussalam. Moving to the next country.
# No import partner found for Cook Islands. Moving to the next country.
# No import partner found for Czechoslovakia. Moving to the next country.
# No import partner found for Equatorial Guinea. Moving to the next country.
# No import partner found for Eritrea. Moving to the next country.
# No import partner found for Ethiopia PDR. Moving to the next country.
# No import partner found for Faroe Islands. Moving to the next country.
# No import partner found for French Guiana. Moving to the next country.
# No import partner found for Guadeloupe. Moving to the next country.
# No import partner found for Marshall Islands. Moving to the next country.
# No import partner found for Martinique. Moving to the next country.
# No import partner found for Niue. Moving to the next country.
# ...

# %%
df2.head()
# Out:
#    Country Area Code              Country  Total Iron consumed per year  \
# 0                  2          Afghanistan                    122.897625
# 1                  3              Albania                     19.121877
# 2                  4              Algeria                    237.971436
# 3                  7               Angola                    106.482179
# 4                  8  Antigua and Barbuda                      0.560594
#
#    Number of import partner countries  \
# 0                               198.0
# 1                               198.0
# 2                               197.0
# 3                               199.0
# 4                               199.0
#
#                        Import partner country name-1  \
# 0                                        Afghanistan
# 1                                            Albania
# 2                                            Algeria
# 3                                             Angola
# ...

# %% [markdown]
# df2.to_csv("table_s1_Vit_C.csv",index=False)

# %%
df2.to_csv("table_s2_Iron.csv",index=False)

# %%
import numpy as np

# %%
# Exports
save_directory = r"C:\Users\ASUS\OneDrive\Desktop\Summary_2.0"
df = pd.read_csv("Cleaned_Data.csv")
for column in df.columns:
    if column in  excluded_columns:
        continue
    df_copy = pd.read_csv("Cleaned_Data.csv")
    grouped_df = df_copy.groupby(['Exporter_Country', 'Importer_Country'])[column].sum().reset_index()
    temp_df = pd.read_csv('Template.csv')
    new_columns = [
    f'Total {column} produced per year',
    'Number of export partner countries',
    'export partner country name-1',
    'export partner country name-2',
    'export partner country name-3',
    'export partner country name-4',
    'export partner country name-5',
    'export partner country name-6',
    f'% of total {column} to export partner-1',
    f'% of total {column} to export partner-2',
    f'% of total {column} to export partner-3',
    f'% of total {column} to export partner-4',
    f'% of total {column} to export partner-5',
    f'% of total {column} to export partner-6']
    for cols in new_columns:
        temp_df[cols] = np.nan
    for country in temp_df['Country']:
        total_energy = 0
        count = 0
        imp_cty = []
        energy = []
        for i in range(len(grouped_df['Exporter_Country'])):
            curr_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Exporter_Country')]
            
            if country == curr_cty:
                Imp_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Importer_Country')]
                Energy = grouped_df.iloc[i, grouped_df.columns.get_loc(column)]
                if(Energy < 0.0001):
                    continue
                total_energy += Energy
                energy.append(Energy)
                imp_cty.append(Imp_cty)
                count += 1
                
        temp_df.loc[temp_df['Country'] == country, f'Total {column} produced per year'] = total_energy
        temp_df.loc[temp_df['Country'] == country, 'Number of export partner countries'] = count
        df = pd.DataFrame({'Imp_Country': imp_cty, 'Energy': energy})
        df.sort_values(by=['Energy'], ascending=False, inplace=True)
        
        try:
            cty_1 = df['Imp_Country'].iloc[0]
            temp_df.loc[temp_df['Country'] == country, 'export partner country name-1'] = cty_1
            cty_2 = df['Imp_Country'].iloc[1]
            temp_df.loc[temp_df['Country'] == country, 'export partner country name-2'] = cty_2
            cty_3 = df['Imp_Country'].iloc[2]
            temp_df.loc[temp_df['Country'] == country, 'export partner country name-3'] = cty_3
            cty_4 = df['Imp_Country'].iloc[3]
            temp_df.loc[temp_df['Country'] == country, 'export partner country name-4'] = cty_4
            cty_5 = df['Imp_Country'].iloc[4]
            temp_df.loc[temp_df['Country'] == country, 'export partner country name-5'] = cty_5
            cty_6 = df['Imp_Country'].iloc[5]
            temp_df.loc[temp_df['Country'] == country, 'export partner country name-6'] = cty_6
            
            calorie_1 = (df['Energy'].iloc[0] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to export partner-1'] = calorie_1
            calorie_2 = (df['Energy'].iloc[1] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to export partner-2'] = calorie_2
            calorie_3 = (df['Energy'].iloc[2] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to export partner-3'] = calorie_3
            calorie_4 = (df['Energy'].iloc[3] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to export partner-4'] = calorie_4
            calorie_5 = (df['Energy'].iloc[4] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to export partner-5'] = calorie_5
            calorie_6 = (df['Energy'].iloc[5] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to export partner-6'] = calorie_6
            
        except IndexError:
            # print(f"No import partner found for {country}. Moving to the next country.")
            continue
    file_path =  f"{save_directory}/Table_S2_{column}.csv"
    temp_df.to_csv(file_path,index=False)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4216\558476810.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Afghanistan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   temp_df.loc[temp_df['Country'] == country, 'export partner country name-1'] = cty_1
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4216\558476810.py:54: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Pakistan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   temp_df.loc[temp_df['Country'] == country, 'export partner country name-2'] = cty_2
# ...

# %%
# Imports
# Exports
save_directory = r"C:\Users\ASUS\OneDrive\Desktop\Summary_2.0"
df = pd.read_csv("Cleaned_Data.csv")
for column in df.columns:
    if column in  excluded_columns:
        continue
    df_copy = pd.read_csv("Cleaned_Data.csv")
    grouped_df = df_copy.groupby(['Importer_Country', 'Exporter_Country'])[column].sum().reset_index()
    temp_df = pd.read_csv('Template.csv')
    new_columns = [
    f'Total {column} consumed per year',
    'Number of import partner countries',
    'import partner country name-1',
    'import partner country name-2',
    'import partner country name-3',
    'import partner country name-4',
    'import partner country name-5',
    'import partner country name-6',
    f'% of total {column} to import partner-1',
    f'% of total {column} to import partner-2',
    f'% of total {column} to import partner-3',
    f'% of total {column} to import partner-4',
    f'% of total {column} to import partner-5',
    f'% of total {column} to import partner-6']
    for cols in new_columns:
        temp_df[cols] = np.nan
    for country in temp_df['Country']:
        total_energy = 0
        count = 0
        exp_cty = []
        energy = []
        for i in range(len(grouped_df['Importer_Country'])):
            curr_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Importer_Country')]
            
            if country == curr_cty:
                Exp_cty = grouped_df.iloc[i, grouped_df.columns.get_loc('Exporter_Country')]
                Energy = grouped_df.iloc[i, grouped_df.columns.get_loc(column)]
                if(Energy < 0.0001):
                    continue
                total_energy += Energy
                energy.append(Energy)
                exp_cty.append(Exp_cty)
                count += 1
                
        temp_df.loc[temp_df['Country'] == country, f'Total {column} consumed per year'] = total_energy
        temp_df.loc[temp_df['Country'] == country, 'Number of import partner countries'] = count
        df = pd.DataFrame({'Exp_Country': exp_cty, 'Energy': energy})
        df.sort_values(by=['Energy'], ascending=False, inplace=True)
        
        try:
            cty_1 = df['Exp_Country'].iloc[0]
            temp_df.loc[temp_df['Country'] == country, 'import partner country name-1'] = cty_1
            cty_2 = df['Exp_Country'].iloc[1]
            temp_df.loc[temp_df['Country'] == country, 'import partner country name-2'] = cty_2
            cty_3 = df['Exp_Country'].iloc[2]
            temp_df.loc[temp_df['Country'] == country, 'import partner country name-3'] = cty_3
            cty_4 = df['Exp_Country'].iloc[3]
            temp_df.loc[temp_df['Country'] == country, 'import partner country name-4'] = cty_4
            cty_5 = df['Exp_Country'].iloc[4]
            temp_df.loc[temp_df['Country'] == country, 'import partner country name-5'] = cty_5
            cty_6 = df['Exp_Country'].iloc[5]
            temp_df.loc[temp_df['Country'] == country, 'import partner country name-6'] = cty_6
            
            calorie_1 = (df['Energy'].iloc[0] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to import partner-1'] = calorie_1
            calorie_2 = (df['Energy'].iloc[1] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to import partner-2'] = calorie_2
            calorie_3 = (df['Energy'].iloc[2] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to import partner-3'] = calorie_3
            calorie_4 = (df['Energy'].iloc[3] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to import partner-4'] = calorie_4
            calorie_5 = (df['Energy'].iloc[4] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to import partner-5'] = calorie_5
            calorie_6 = (df['Energy'].iloc[5] / total_energy) * 100
            temp_df.loc[temp_df['Country'] == country, f'% of total {column} to import partner-6'] = calorie_6
            
        except IndexError:
            print(f"No export partner found for {country}. Moving to the next country.")
            continue
    file_path =  f"{save_directory}/Table_S1_{column}.csv"
    temp_df.to_csv(file_path,index=False)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4216\195745822.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Afghanistan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   temp_df.loc[temp_df['Country'] == country, 'import partner country name-1'] = cty_1
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4216\195745822.py:55: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Kazakhstan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   temp_df.loc[temp_df['Country'] == country, 'import partner country name-2'] = cty_2
# ...
